# %% [markdown]
# Chapter2: Distributions

# %%
import sys
import os

print(sys.executable)
print(os.getcwd())
# Out:
# /home/samantoz/git_repos/ThinkStats2/practice/.venv/bin/python
# /home/samantoz/git_repos/ThinkStats2/practice/code/src

# %%
import thinkstats2
# import lib.thinkplot
# import lib.nsfg
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import thinkstats2
#       2 # import lib.thinkplot
#       3 # import lib.nsfg
#
# File ~/git_repos/ThinkStats2/practice/code/src/thinkstats2.py:32
#      29 from collections import Counter
#      30 from operator import itemgetter
# ---> 32 import thinkplot
#      34 import numpy as np
#      35 import pandas
#
# ModuleNotFoundError: No module named 'thinkplot'

# %%
hist = thinkstats2.Hist([1, 2, 2, 3, 5])
hist

# %%
hist.Freq(2)

# %%
hist.Values()

# %%
for val, freq in hist.Items():
    print(val, freq)

# %%
thinkplot.Hist(hist)
thinkplot.Show(xlabel='value', ylabel='frequency')

# %%
preg = nsfg.ReadFemPreg()
live = preg[preg.outcome == 1]

# %%
hist = thinkstats2.Hist(live.birthwgt_lb, label='birthwgt_lb')
thinkplot.Hist(hist)
thinkplot.Show(xlabel='pounds', ylabel='frequency')

# %%
hist = preg
